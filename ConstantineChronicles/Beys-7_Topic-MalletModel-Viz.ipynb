# %% [markdown]
# # 7-Topic Model of the Constantine Beys Corpus
#
# ## Methods
#
# ### Preprocessing
# To prepare the corpus, I split each of the three volumes of chronicles about the governors of Ottoman Constantine, Algeria by governor (or "Bey"). I then used the standard French stopword list [link to list used], adding to it the name of the province (Constantine), and the names of the governors to refine the "bags of words" for each document. In my initial 5-topic experiments, the place and individual names cluttered up the topics and unnecessarily complicated analysis because I became distracted trying to link the toipcs to time using the names of the beys included. That proved very unhelpful though because some topics had so many names that there were few other words to provide enough context to label the topic.
#
# ## Summary Analysis
#
# A quick comparison of the 5-topic model and the 7-topic model gives us the following sets of topic labels, and we can already see some of the topics that appear in every model, even the much larger models. These topics appear in bold below.
#
# ><em>5-Topic Model:</em> Indigenous politics, <b>Leadership & Succession</b>, <b>Fall of Constantine</b>, Negotiations of Ahmed Bey, and Administration
#
# ><em>7-Topic Model:</em> <b>Ottoman-Tribal Negotiations</b> [which were not always peaceful, thus we see a number of military terms in this topic across the models], <b>Tribal rebellions</b>, <b>Leadership & Succession</b>, <b>Religion</b> [does not yet make the connection between religion and governance in the region], <b>Internal political upheaval</b>, <b>Public works</b>, and the <b>Fall of Constantine</b> to the French in 1837.

# %% [markdown]
# ## Experimental Visualizations

# %%
import pandas as pd

oa7_topics = pd.Cov = pd.read_csv("/Users/asg/mallet/output/OA-model/oa7-keys.csv", sep=',', names=["topic_number", "topic_weight", "top_words"])

oa7_topics.style.set_properties(subset=['top_words'], **{'width': '600px'})
# Out:
# <style  type="text/css" >
#     #T_753bf460_7f3e_11ea_8a9d_acde48001122row0_col2 {
#             width:  600px;
#         }    #T_753bf460_7f3e_11ea_8a9d_acde48001122row1_col2 {
#             width:  600px;
#         }    #T_753bf460_7f3e_11ea_8a9d_acde48001122row2_col2 {
#             width:  600px;
#         }    #T_753bf460_7f3e_11ea_8a9d_acde48001122row3_col2 {
#             width:  600px;
#         }    #T_753bf460_7f3e_11ea_8a9d_acde48001122row4_col2 {
#             width:  600px;
#         }    #T_753bf460_7f3e_11ea_8a9d_acde48001122row5_col2 {
#             width:  600px;
#         }    #T_753bf460_7f3e_11ea_8a9d_acde48001122row6_col2 {
#             width:  600px;
#         }</style>
# <table id="T_753bf460_7f3e_11ea_8a9d_acde48001122" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >topic_number</th>
#         <th class="col_heading level0 col1" >topic_weight</th>
#         <th class="col_heading level0 col2" >top_words</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_753bf460_7f3e_11ea_8a9d_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row0_col0" class="data row0 col0" >0</td>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row0_col1" class="data row0 col1" >0.20924</td>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row0_col2" class="data row0 col2" >janissaires milice région gana kaïd mokrani france hadj troupes chaouchs négociations réussit makhzen français sud diwan sultan saïd biens ouled </td>
#     </tr>    <tr>
#         <th id="T_753bf460_7f3e_11ea_8a9d_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row1_col0" class="data row1 col0" >1</td>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row1_col1" class="data row1 col1" >0.18729</td>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row1_col2" class="data row1 col2" >dey sud tunisie région henanecha nommé kabiles daouaouida ben-gana l’autorité révolte famille décida notamment medjana indigènes grand règne yoldach régions </td>
#     </tr>    <tr>
#         <th id="T_753bf460_7f3e_11ea_8a9d_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row2_col0" class="data row2 col0" >2</td>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row2_col1" class="data row2 col1" >1.53826</td>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row2_col2" class="data row2 col2" >bey qu’il ville faire d’une pacha alger temps tunis d’alger troupes d’un mort dey province fils tête turcs camp hommes </td>
#     </tr>    <tr>
#         <th id="T_753bf460_7f3e_11ea_8a9d_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row3_col0" class="data row3 col0" >3</td>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row3_col1" class="data row3 col1" >0.15341</td>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row3_col2" class="data row3 col2" >cheïkh dieu l’hégire d’ali mourut beys d’ailleurs l’histoire j.-c sidi s’est écrit années n’a mosquée régence arabe l’année devons aujourd’hui </td>
#     </tr>    <tr>
#         <th id="T_753bf460_7f3e_11ea_8a9d_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row4_col0" class="data row4 col0" >4</td>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row4_col1" class="data row4 col1" >0.14346</td>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row4_col2" class="data row4 col2" >makhzen caïd-dar l’usurpateur dieu membres chaouch biens d’ailleurs chaouche nommé bach-agha plaintes foule khalifa yeux parut tentes bach-kateb aujourd’hui composition </td>
#     </tr>    <tr>
#         <th id="T_753bf460_7f3e_11ea_8a9d_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row5_col0" class="data row5 col0" >5</td>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row5_col1" class="data row5 col1" >0.07519</td>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row5_col2" class="data row5 col2" >tribu touggourt pont zmala marabout musulmans qu’un qu’elle medersa construire règlement réaux arches espagnols chameaux mieux n’avaient batna espagnole hanek </td>
#     </tr>    <tr>
#         <th id="T_753bf460_7f3e_11ea_8a9d_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row6_col0" class="data row6 col0" >6</td>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row6_col1" class="data row6 col1" >0.0368</td>
#         <td id="T_753bf460_7f3e_11ea_8a9d_acde48001122row6_col2" class="data row6 col2" >général rue bône ben-gana france brèche feu batterie duc assiégés commandant colonel mansoura bataillon maréchal ville koudiat commandement l’armée nemours </td>
#     </tr></tbody>
# </table>

# %%
# Create a list of topic labels.
labels = ['Ott-Tribes-Neg', 'Tribal rebellions', 'Leadership_Succession', 'Religion', 'Internal discord', 'Public works', 'Battle of Constantine']

# Add the labels list as a new column to the dataframe
oa7_topics['labels'] = labels

# Adjust the style of the dataframe so that the column of top_words is wide enough to see all of them.
oa7_topics.style.set_properties(subset=['top_words'], **{'width': '500px'})
# Out:
# <style  type="text/css" >
#     #T_7dc2e240_7f40_11ea_8a9d_acde48001122row0_col2 {
#             width:  500px;
#         }    #T_7dc2e240_7f40_11ea_8a9d_acde48001122row1_col2 {
#             width:  500px;
#         }    #T_7dc2e240_7f40_11ea_8a9d_acde48001122row2_col2 {
#             width:  500px;
#         }    #T_7dc2e240_7f40_11ea_8a9d_acde48001122row3_col2 {
#             width:  500px;
#         }    #T_7dc2e240_7f40_11ea_8a9d_acde48001122row4_col2 {
#             width:  500px;
#         }    #T_7dc2e240_7f40_11ea_8a9d_acde48001122row5_col2 {
#             width:  500px;
#         }    #T_7dc2e240_7f40_11ea_8a9d_acde48001122row6_col2 {
#             width:  500px;
#         }</style>
# <table id="T_7dc2e240_7f40_11ea_8a9d_acde48001122" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >topic_number</th>
#         <th class="col_heading level0 col1" >topic_weight</th>
#         <th class="col_heading level0 col2" >top_words</th>
#         <th class="col_heading level0 col3" >labels</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_7dc2e240_7f40_11ea_8a9d_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row0_col0" class="data row0 col0" >0</td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row0_col1" class="data row0 col1" >0.20924</td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row0_col2" class="data row0 col2" >janissaires milice région gana kaïd mokrani france hadj troupes chaouchs négociations réussit makhzen français sud diwan sultan saïd biens ouled </td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row0_col3" class="data row0 col3" >Ott-Tribes-Neg</td>
#     </tr>    <tr>
#         <th id="T_7dc2e240_7f40_11ea_8a9d_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row1_col0" class="data row1 col0" >1</td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row1_col1" class="data row1 col1" >0.18729</td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row1_col2" class="data row1 col2" >dey sud tunisie région henanecha nommé kabiles daouaouida ben-gana l’autorité révolte famille décida notamment medjana indigènes grand règne yoldach régions </td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row1_col3" class="data row1 col3" >Tribal rebellions</td>
#     </tr>    <tr>
#         <th id="T_7dc2e240_7f40_11ea_8a9d_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row2_col0" class="data row2 col0" >2</td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row2_col1" class="data row2 col1" >1.53826</td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row2_col2" class="data row2 col2" >bey qu’il ville faire d’une pacha alger temps tunis d’alger troupes d’un mort dey province fils tête turcs camp hommes </td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row2_col3" class="data row2 col3" >Leadership_Succession</td>
#     </tr>    <tr>
#         <th id="T_7dc2e240_7f40_11ea_8a9d_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row3_col0" class="data row3 col0" >3</td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row3_col1" class="data row3 col1" >0.15341</td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row3_col2" class="data row3 col2" >cheïkh dieu l’hégire d’ali mourut beys d’ailleurs l’histoire j.-c sidi s’est écrit années n’a mosquée régence arabe l’année devons aujourd’hui </td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row3_col3" class="data row3 col3" >Religion</td>
#     </tr>    <tr>
#         <th id="T_7dc2e240_7f40_11ea_8a9d_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row4_col0" class="data row4 col0" >4</td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row4_col1" class="data row4 col1" >0.14346</td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row4_col2" class="data row4 col2" >makhzen caïd-dar l’usurpateur dieu membres chaouch biens d’ailleurs chaouche nommé bach-agha plaintes foule khalifa yeux parut tentes bach-kateb aujourd’hui composition </td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row4_col3" class="data row4 col3" >Internal discord</td>
#     </tr>    <tr>
#         <th id="T_7dc2e240_7f40_11ea_8a9d_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row5_col0" class="data row5 col0" >5</td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row5_col1" class="data row5 col1" >0.07519</td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row5_col2" class="data row5 col2" >tribu touggourt pont zmala marabout musulmans qu’un qu’elle medersa construire règlement réaux arches espagnols chameaux mieux n’avaient batna espagnole hanek </td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row5_col3" class="data row5 col3" >Public works</td>
#     </tr>    <tr>
#         <th id="T_7dc2e240_7f40_11ea_8a9d_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row6_col0" class="data row6 col0" >6</td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row6_col1" class="data row6 col1" >0.0368</td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row6_col2" class="data row6 col2" >général rue bône ben-gana france brèche feu batterie duc assiégés commandant colonel mansoura bataillon maréchal ville koudiat commandement l’armée nemours </td>
#         <td id="T_7dc2e240_7f40_11ea_8a9d_acde48001122row6_col3" class="data row6 col3" >Battle of Constantine</td>
#     </tr></tbody>
# </table>

# %%
# Represent the weights of the topics as a simple bar chart, using the author-created topic labels. 

topic_bar = oa7_topics.plot.bar(x='labels', y='topic_weight', rot=0, figsize=(17,5))

# %%
# The mallet .txt doc-topics output file was converted to a csv, and the columns for 
# document numbers and filepaths were deleted in advance of reading the csv into a 
# pandas dataframe. Be sure to convert the columns to number data type with ~6 decimal places to remove the 
# exponential format. Also, add a new line at the top of the csv with the labels defined in the previous step.

oa7_docs = pd.Cov = pd.read_csv("/Users/asg/mallet/output/OA-model/oa7-doc-topics.csv", sep=',')

# Uncomment the following line to view dataframe
#oa7_docs

# %%
# Represent the topic weights in each document as a heatmap.

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

plt.rcParams['figure.figsize'] = (17.0, 10.0)

oa7_docs = oa7_docs[oa7_docs.columns].astype(float)  # or int

# Create a heatmap that is visually accessible (see https://matplotlib.org/tutorials/colors/colormaps.html)
# using the 'inferno' colormap. 

sns.heatmap(oa7_docs, cmap='inferno', vmin=0.0, vmax=1.0)

# %%
# Create a hierarchical heatmap using seaborn's "clustermap" method with default settings.
# By default this method will cluster by both rows and columns, which is what is most useful for this data.

sns.clustermap(oa7_docs, cmap='inferno')

# %% [markdown]
# ## Visualizing Mallet output with pyLDAvis
# You will need to generate MALLET's output-topic-states <b>gz</b> file to prepare the MALLET output in the format needed by pyLDAvis. I didn't know about this possibility, so I had to run MALLET again, creating a different 5-topic model than the ones visualized above.
#
# Huge thanks to <a href="https://jeriwieringa.com/about/">Jeri E. Wieringa</a> for making this connection and sharing all of the code! You can find her explanation and code at <a href="https://jeriwieringa.com/2018/07/17/pyLDAviz-and-Mallet/">"Using pyLDAvis with Mallet."</a>

# %%
import pandas as pd
import gzip
import os

dataDir = "/Users/asg/mallet/output/OA-model/"

def extract_params(statefile):
    """Extract the alpha and beta values from the statefile. 
    
    Args:
        statefile (str): Path to the statefile produced by Mallet.
    Returns:
        tuple: alpha (list), beta
    """
    with gzip.open(statefile, 'r') as state:
        params = [x.decode('utf-8').strip() for x in state.readlines()[1:3]]
    return (list(params[0].split(":")[1].split(" ")), float(params[1].split(":")[1]))

def state_to_df(statefile):
    """Transform state file into pandas dataframe. 
    The Mallet statefile is tab-separated, and the first two rows contain the alpha and beta hyperparameters.
    
    Args:
        statefile (str): Path to statefile produced by Mallet.
    Returns:
        dataframe: topic assignment for each token in each document of the model
    """
    return pd.read_csv(statefile,
                      compression='gzip',
                      sep=' ',
                      skiprows=[1,2]
                      )

# %%
params = extract_params(os.path.join(dataDir, 'oa7-topic-state.gz'))

alpha = [float(x) for x in params[0][1:]]
beta = params[1]
print("{}, {}".format(alpha, beta))

df = state_to_df(os.path.join(dataDir, 'oa7-topic-state.gz'))
# Out:
# [0.2092361057942648, 0.1872885426405114, 1.5382614811765818, 0.15340806707079577, 0.14346035201039123, 0.07519104673292655, 0.03680294976259712], 0.15939099658638048

# %%
# Define column 'type' as a string to avoid nan pandas errors.
df['type'] = df.type.astype(str)

# Preview the dataframe from the statefile, which will then be used to generate the data needed for the 
# LDAvis library. 
df[:4]
# Out:
#    #doc                   source  pos  typeindex        type  topic
# 0     0  data/OttAlg/gaid-36.txt    0          0  naaman-bey      0
# 1     0  data/OttAlg/gaid-36.txt    1          1         mai      2
# 2     0  data/OttAlg/gaid-36.txt    2          2        turc      2
# 3     0  data/OttAlg/gaid-36.txt    3          3   naissance      2

# %% [markdown]
# <b>Step 1:</b> We need the length of the documents. To do this, Jeri grouped the data by document id and counted the tokens in the doc. This data is then sorted by the doc id, so it will be in the correct order for visualization pre-processing.

# %%
# Get document lengths from statefile.
docs = df.groupby('#doc')['type'].count().reset_index(name='doc_length')

# Preview the gathered & grouped data:
docs[:4]
# Out:
#    #doc  doc_length
# 0     0         608
# 1     1           2
# 2     2          17
# 3     3         321

# %% [markdown]
# <b>Step 2:</b> We need the voabulary and frequencies. Jeri used pandas to generate a new frame with the word counts. She then sorted this df so that it is alphabetical by type, a step that will need to be repeated when creating the topic-term matrix because the order matters and must be kept consistent. Just as in Jeri's example, I, too, have OCR errors (see the first entry in the vocab dataframe above).

# %%
# Get vocab and term frequencies from the statefile.
vocab = df['type'].value_counts().reset_index()
vocab.columns = ['type', 'term_freq']
vocab = vocab.sort_values(by='type', ascending=True)

# Preview the resulting dataframe
vocab[:4]
# Out:
#               type  term_freq
# 14610        a*tes          1
# 13447     a-t-elle          1
# 5173        a-t-il          3
# 7871   abaissement          2

# %% [markdown]
# <b>Step 3:</b> Create matrix files. The values need to be smoothed and the data normalized so that each row sums to 1. Jeri used sklearn to handle large matrices efficiently.

# %%
# Topic-term matrix from state file.

import sklearn.preprocessing

def pivot_and_smooth(df, smooth_value, rows_variable, cols_variable, values_variable):
    """
    Turns the pandas dataframe into a data matrix.
    Args:
        df (dataframe): aggregated dataframe
        smooth_value (float): value to add to the matrix to account for the priors
        rows_variable (str): name of dataframe row to use as the rows in the matrix
        cols_variable (str): name of dataframe column to use as the columns in the matrix
        values_variable (str): name of the dataframe column to use as the values in the matrix
    Returns:
        dataframe: pandas matrix that has been normalized on the rows
    """
    matrix = df.pivot(index=rows_variable, columns=cols_variable, values=values_variable).fillna(value=0)
    matrix = matrix.values + smooth_value
    normed = sklearn.preprocessing.normalize(matrix, norm='l1', axis=1)
    return pd.DataFrame(normed)

# %% [markdown]
# <b>Step 4:</b> [From Jeri's post] Next, we need to aggregate the data from the statefile dataframe to get the nmber of topic assignments for words in the documents. For <b>phi</b>, the topic-term matrix, [she] aggregated by topic and word, counted the number of times each word was assigned to each topic, and then sorted the resulting dataframe alphabetically by word, so that it matches the order of the vocabulary frame. Here, [she] used the <b>beta</b> hyperparameter as the smoothing value.

# %%
phi_df = df.groupby(['topic', 'type'])['type'].count().reset_index(name ='token_count')
phi_df = phi_df.sort_values(by='type', ascending=True)

phi_df[:10]

phi = pivot_and_smooth(phi_df, beta, 'topic', 'type', 'token_count')

phi[:10]
# Out:
#       0         1         2         3         4         5         6      \
# 0  0.000015  0.000015  0.000015  0.000015  0.000015  0.000015  0.000015
# 1  0.000016  0.000016  0.000016  0.000016  0.000016  0.000115  0.000115
# 2  0.000003  0.000003  0.000003  0.000045  0.000003  0.000003  0.000003
# 3  0.000158  0.000158  0.000022  0.000022  0.000022  0.000022  0.000022
# 4  0.000018  0.000018  0.000134  0.000018  0.000018  0.000018  0.000250
# 5  0.000025  0.000025  0.000025  0.000025  0.000025  0.000025  0.000025
# 6  0.000018  0.000018  0.000239  0.000018  0.000128  0.000018  0.000128
#
#       7         8         9        ...        16844     16845     16846  \
# 0  0.000015  0.000015  0.000015    ...     0.000015  0.000015  0.000015
# 1  0.000016  0.000016  0.000016    ...     0.000215  0.000016  0.000016
# 2  0.000087  0.000003  0.000003    ...     0.000003  0.000003  0.000003
# 3  0.000158  0.000022  0.000158    ...     0.000022  0.000022  0.000158
# 4  0.000366  0.000134  0.000018    ...     0.000018  0.000018  0.000018
# 5  0.000025  0.000025  0.000025    ...     0.000025  0.000179  0.000025
# 6  0.000018  0.000018  0.000018    ...     0.000018  0.000018  0.000018
#
#       16847     16848     16849     16850     16851     16852     16853
# 0  0.000015  0.000015  0.000015  0.000293  0.000015  0.000108  0.000108
# 1  0.000016  0.000016  0.000016  0.000016  0.000016  0.000016  0.000016
# 2  0.000003  0.000003  0.000066  0.000003  0.000003  0.000024  0.000003
# 3  0.000022  0.000158  0.000022  0.000022  0.000840  0.000295  0.000022
# 4  0.000134  0.000018  0.000018  0.000018  0.000018  0.000018  0.000018
# 5  0.000025  0.000025  0.000025  0.000025  0.000025  0.000025  0.000025
# 6  0.000018  0.000018  0.000018  0.000018  0.000460  0.000018  0.000018
#
# [7 rows x 16854 columns]

# %% [markdown]
# <b>Step 5:</b> We do the same thing again, but focused on the documents and topics (rather than words & topics) to generate the <b>theta</b> document-topic matrix. Here, <b>alpha</b> is used as the smoothing value.

# %%
theta_df = df.groupby(['#doc', 'topic'])['topic'].count().reset_index(name ='topic_count')

theta_df[:10]

theta = pivot_and_smooth(theta_df, alpha, '#doc', 'topic', 'topic_count')

theta[:10]
# Out:
#           0         1         2         3         4         5         6
# 0  0.477123  0.000307  0.485855  0.000251  0.000235  0.036168  0.000060
# 1  0.048171  0.273339  0.584362  0.035318  0.033028  0.017311  0.008473
# 2  0.010817  0.216468  0.389702  0.369807  0.007416  0.003887  0.001903
# 3  0.235691  0.000579  0.505772  0.257167  0.000444  0.000233  0.000114
# 4  0.501704  0.025963  0.423469  0.048054  0.000455  0.000238  0.000117
# 5  0.039156  0.409325  0.475005  0.028708  0.026847  0.014071  0.006887
# 6  0.278392  0.043118  0.584362  0.035318  0.033028  0.017311  0.008473
# 7  0.350657  0.001452  0.514848  0.005413  0.127556  0.000050  0.000024
# 8  0.001094  0.115955  0.880815  0.000802  0.000750  0.000393  0.000192
# 9  0.422061  0.002765  0.525309  0.042282  0.000334  0.007163  0.000086

# %% [markdown]
# The above processing steps represent about 90% of the work needed to prepare the mallet data for visualization with the LDAvis library. Now that all of the data has been formatted for pyLDAvis, we can queue it up and pass it to the visualization library.

# %%
import pyLDAvis

data = {'topic_term_dists': phi,
        'doc_topic_dists': theta,
        'doc_lengths': list(docs['doc_length']),
        'vocab': list(vocab['type']),
        'term_frequency': list(vocab['term_freq'])
}

vis_data = pyLDAvis.prepare(**data)

pyLDAvis.display(vis_data)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4027848956941846147754868"></div>
# <script type="text/javascript">
#
# var ldavis_el4027848956941846147754868_data = {"mdsDat": {"x": [0.3109220888832392, -0.0184195322609371, -0.05212517399440355, -0.0293044409155588, -0.06687364709330604, -0.0760997754405326, -0.06809951917850192], "y": [0.02046300525659604, -0.20830422431266507, -0.04715026569658052, 0.09321994375925255, 0.059413657488688654, 0.04293411940782577, 0.039423764096882453], "topics": [1, 2, 3, 4, 5, 6, 7], "cluster": [1, 1, 1, 1, 1, 1, 1], "Freq": [55.57675234556557, 9.910848719681384, 9.053498037939535, 7.808504244853497, 7.303818392946561, 5.701323266713519, 4.645254992299919]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Top ...
