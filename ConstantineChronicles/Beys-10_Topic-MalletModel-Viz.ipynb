# %% [markdown]
# # 10-Topic Model of the Constantine Beys Corpus
#
# ## Methods
#
#
#
# ## Summary of Findings
#
# There is a lot of consistency across the models of 5, 7, 9, and 10 topics so far. The primary topic (1 here) deals with the governors' responsibilities and leadership transitions. This makes complete sense since chronicles comprise the corpus. Then, there is a small cluster of two topics that focus on the power struggle between, and among, the janissaries/militia, governor, and local tribes. There is a slight inflection toward negotiations in topic 2 and rebellion in topic 3, which differentiates the two. Topic 4 focuses on the 1836 and 1837 battles of/for Constantine during the French invasion, and topic 5 deals with Islamic religious practices, but the rest of the topics represent the minutia of local politics. Topic 6 describes the conflict between Tunis and Algiers over control of Constantine, include the 1806 Tunisian siege and the Algerian defense of the fortified city. Topic 7 highlights the members of the governors' council and their movements, which is closely related to the themes of internal political appointments and dissension that appear in topic 8. Topic 9 covers the French concession at La Calle, and topic 10 shines a light on several specific beys and their bad behavior, especially Dali Bey.

# %% [markdown]
# ## Experimental Visualizations

# %%
import pandas as pd

oa10_topics = pd.Cov = pd.read_csv("/Users/asg/mallet/output/OA-model/oa10-keys.csv", sep=',', names=["topic_number", "topic_weight", "top_words"])

oa10_topics.style.set_properties(subset=['top_words'], **{'width': '600px'})
# Out:
# <style  type="text/css" >
#     #T_f1a44bba_7b38_11ea_96d6_82df45250401row0_col2 {
#             width:  600px;
#         }    #T_f1a44bba_7b38_11ea_96d6_82df45250401row1_col2 {
#             width:  600px;
#         }    #T_f1a44bba_7b38_11ea_96d6_82df45250401row2_col2 {
#             width:  600px;
#         }    #T_f1a44bba_7b38_11ea_96d6_82df45250401row3_col2 {
#             width:  600px;
#         }    #T_f1a44bba_7b38_11ea_96d6_82df45250401row4_col2 {
#             width:  600px;
#         }    #T_f1a44bba_7b38_11ea_96d6_82df45250401row5_col2 {
#             width:  600px;
#         }    #T_f1a44bba_7b38_11ea_96d6_82df45250401row6_col2 {
#             width:  600px;
#         }    #T_f1a44bba_7b38_11ea_96d6_82df45250401row7_col2 {
#             width:  600px;
#         }    #T_f1a44bba_7b38_11ea_96d6_82df45250401row8_col2 {
#             width:  600px;
#         }    #T_f1a44bba_7b38_11ea_96d6_82df45250401row9_col2 {
#             width:  600px;
#         }</style>
# ...

# %% [markdown]
# ## Initial analysis of the topics and their meanings:
#
# The <b>first</b> topic is a little muddled because it also includes information about Mustafa-Ingliz, the bey who was raised and educated in England, as well as Osman Bey and Dali Bey. The latter provoked an "outcry" for his "extreme" and cruel behavior, certainly earning the label "despot." However, I am going to have to go back to the documents to see how the other words fit (bel-ahrech, cherif, course, bouche, oulad-derradj, ammar, msila). Most of these are places, individuals or people groups.
#
# The <b>second</b> topic is about the French coral fishing concession at La Calle (france, bastion, calle, compagnie, l'autorité, établissemeents, consul, agents, privilèges). I believe the references to the divan (diwan) point to the divan's advice on Algeria's relationship with the French bastion. I'll have to go back and review Moustafa El Ouznadji's chronicle to see why his name is connected with the concession, but this is a really coherent topic. Two other words stand out that may deserve a little attention - "femme" and "peste." Of course, plague hit port cities, as La Calle was, particularly hard, so it shouldn't be too surprising to see it here, but I'm curious if it caused an unusually noteworthy incident.
#
# The <b>third</b> topic coheres around issues of internal political appointments, posturing, and dissension, which was common throughout the Ottoman period, especially in Algiers:
# <ul>
#     <li>internal political appointments:
#         <ol>
#             <li>maison</li>
#             <li>bach-agha</li>
#             <li>chaouch(e)</li>
#             <li>agha</li>
#             <li>joug [yoke]</li>
#             <li>dar-el-bey [territory/province of the bey]</li>
#     </ol>
#     <li>dissension:
#         <ol>
#             <li>l'usurpateur</li>
#             <li>oreilles [ears]</li>
#             <li>sang</li>
#             <li>meurtre</li>
#             <li>crimes</li>
#         </ol>
#     </li>
# </ul>
#
# <b>Fourth:</b> members of the Mahkzen, or the governor's council <em>(diwan or divan)</em> and their movements (khalifa, or lieutenant-governor, membres, composition; aller, porter, partir. It also points to (their? or the governor's?) emotional states (plaisir and plaintes), wrongdoing (coupable, prison, and, perhaps, foule), as well as, perhaps, punishment (têtes - as in their reomval). I'll have to go back to the documents most strongly correlated with this topic to find out.
#
# <b>Fifth:</b> Fall of Constantine
#
# <b>Sixth:</b> I'm still having trouble labeling this topic, but it appears in every model. It has to do with the governor and his decisions/leadership in every model. In this model, the focus seems to be on his role as the military leader of the province. Traditionally, in Ottoman provinces, the Beylerbeyi or Bey was a general, and his responsibilities were primarily military and financial (ctax collection and submission), and this was also true, although with much less consequence to the larger empire, in Algeria's provinces. We can see this reflected in the collection of collocated words (troupes, province, turcs, tête, hommes, camp). However, we also see references to transitions in leadership, which were determined by the <b>dey</b> in <b>Alger [Algiers]</b>. These transitions were necessary when the sitting bey died (<b>mort</b>). A number of these deaths were either of natural causes or occurred in battle, but increasingly in the nineteenth, the <b>pacha</b> in Algiers ordered the current bey's assassination in order to install (place) a new governor more to the pacha's liking.
#
# <b>Seventh:</b> Religion and piety: dieu, mosquée, Zmala, hégire, vendredi (holy day), construire, and réaux (Algerian reals=money).
#
# <b>Eighth:</b> Negotiation of local leadership between some of the tribes most involved in regional governance, such as the Muqrani (mokrani), Ben Gana, Ouled-____(Tribe), janissaries, mahkzen, chaouchs, troupes.
#
# <b>Ninth:</b> Tribal revolts <b>(révolte)</b>, especially the Grand Tribes and those in the south <b>(sud)</b>, as well as the Kabyles (kabile). Those who were most often cited included the Henanecha, Daouaouida, and Ben Gana. These are also the tribes into which many of the Ottoman elite married, generally to try to quell rebellions by forming strategic alliances. We also see the juxtaposition of colonists (colonne) and "indigènes," a conflict that superceded concerns about the tribes in the nineteenth century with the arrival of European settlers and the French military.
#
# <b>Tenth:</b>Tunisian-Algerian conflict, in which Constantine was the frontier. It was such a desirable region that Algiers and Tunis fought for control over it, so a number of military terms appear in this topic (siege, déroute, armées, réunir, troupes). Interestingly, the term <b>fille</b> (daughter) also appears, and now I'm curious to go back and see why it might be linked to this topic. If memory serves, there may have been some cross-border marriages arranged in negotiations and attempts to make peace.
#
# ### Summary:
#
# <ol>
#     <li>I think this topic might be a mashup or chimera of the 1816 bombardment of Algiers by the English Admiral and the cruelty of a couple of the beys (cruauté, crimes, despote)</li>
#     <li>French concession at La Calle. Notice that both <b>filles</b> and <b>femme</b> appear in this topic. This is something worth looking into to see what the connection might be.</li>
#     <li>Internal political discord</li>
#     <li>Members of the Mahkzen and their movements.</li>
#     <li>Battle of Constantine</li>
#     <li>Leadership & transition</li>
#     <li>Islamic religious practices</li>
#     <li>Negotiations between the Ottomans & local tribes</li>
#     <li>Tribal rebellions</li>
#     <li>Tunisian-Algerian Conflict</li>
# </ol>

# %%
# Create a list of topic labels.
labels = ['Bad govs', 'French concess','Internal dissension', 'Councilmen', 'battle of Con.', 'Lead. & transition', 'Religion', 'Local Leaders', 'Revolts', 'Tunisan-Alg Conflict']

# Add the labels list as a new column to the dataframe
oa10_topics['labels'] = labels

# Adjust the style of the dataframe so that the column of top_words is wide enough to see all of them.
oa10_topics.style.set_properties(subset=['top_words'], **{'width': '500px'})
# Out:
# <style  type="text/css" >
#     #T_beb7268e_7b40_11ea_96d6_82df45250401row0_col2 {
#             width:  500px;
#         }    #T_beb7268e_7b40_11ea_96d6_82df45250401row1_col2 {
#             width:  500px;
#         }    #T_beb7268e_7b40_11ea_96d6_82df45250401row2_col2 {
#             width:  500px;
#         }    #T_beb7268e_7b40_11ea_96d6_82df45250401row3_col2 {
#             width:  500px;
#         }    #T_beb7268e_7b40_11ea_96d6_82df45250401row4_col2 {
#             width:  500px;
#         }    #T_beb7268e_7b40_11ea_96d6_82df45250401row5_col2 {
#             width:  500px;
#         }    #T_beb7268e_7b40_11ea_96d6_82df45250401row6_col2 {
#             width:  500px;
#         }    #T_beb7268e_7b40_11ea_96d6_82df45250401row7_col2 {
#             width:  500px;
#         }    #T_beb7268e_7b40_11ea_96d6_82df45250401row8_col2 {
#             width:  500px;
#         }    #T_beb7268e_7b40_11ea_96d6_82df45250401row9_col2 {
#             width:  500px;
#         }</style>
# ...

# %%
# Represent the weights of the topics as a simple bar chart, using the author-created topic labels. 

topic_bar = oa10_topics.plot.bar(x='labels', y='topic_weight', rot=0, figsize=(20,5))

# %%
# The mallet .txt doc-topics output file was converted to a csv, and the columns for 
# document numbers and filepaths were deleted in advance of reading the csv into a 
# pandas dataframe. Be sure to convert the columns to number data type with ~6 decimal places to remove the 
# exponential format. Also, add a new line at the top of the csv with the labels defined in the previous step.

oa10_docs = pd.Cov = pd.read_csv("/Users/asg/mallet/output/OA-model/oa10-doc-topics.csv", sep=',')

# Uncomment the following line to view dataframe
#oa10_docs

# %%
# Represent the topic weights in each document as a heatmap.

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

plt.rcParams['figure.figsize'] = (17.0, 10.0)

oa10_docs = oa10_docs[oa10_docs.columns].astype(float)

# Create a heatmap that is visually accessible (see https://matplotlib.org/tutorials/colors/colormaps.html)
# using the 'inferno' colormap. 

sns.heatmap(oa10_docs, cmap='inferno', vmin=0.0, vmax=1.0)

# %%
# Create a hierarchical heatmap using seaborn's "clustermap" method with default settings.
# By default this method will cluster by both rows and columns, which is what is most useful for this data.

sns.clustermap(oa10_docs, cmap='inferno')

# %% [markdown]
# ## Visualizing Mallet output with pyLDAvis
# You will need to generate MALLET's output-topic-states <b>gz</b> file to prepare the MALLET output in the format needed by pyLDAvis. I didn't know about this possibility, so I had to run MALLET again, creating a different 5-topic model than the ones visualized above.
#
# Huge thanks to <a href="https://jeriwieringa.com/about/">Jeri E. Wieringa</a> for making this connection and sharing all of the code! You can find her explanation and code at <a href="https://jeriwieringa.com/2018/07/17/pyLDAviz-and-Mallet/">"Using pyLDAvis with Mallet."</a>

# %%
import pandas as pd
import gzip
import os

dataDir = "/Users/asg/mallet/output/OA-model/"

def extract_params(statefile):
    """Extract the alpha and beta values from the statefile. 
    
    Args:
        statefile (str): Path to the statefile produced by Mallet.
    Returns:
        tuple: alpha (list), beta
    """
    with gzip.open(statefile, 'r') as state:
        params = [x.decode('utf-8').strip() for x in state.readlines()[1:3]]
    return (list(params[0].split(":")[1].split(" ")), float(params[1].split(":")[1]))

def state_to_df(statefile):
    """Transform state file into pandas dataframe. 
    The Mallet statefile is tab-separated, and the first two rows contain the alpha and beta hyperparameters.
    
    Args:
        statefile (str): Path to statefile produced by Mallet.
    Returns:
        dataframe: topic assignment for each token in each document of the model
    """
    return pd.read_csv(statefile,
                      compression='gzip',
                      sep=' ',
                      skiprows=[1,2]
                      )

# %%
params = extract_params(os.path.join(dataDir, 'oa10-topic-state.gz'))

alpha = [float(x) for x in params[0][1:]]
beta = params[1]
print("{}, {}".format(alpha, beta))

df = state_to_df(os.path.join(dataDir, 'oa10-topic-state.gz'))
# Out:
# [0.04497921727042979, 0.22174612331892826, 0.0757644476894436, 0.13135124607342147, 0.023015933795246187, 1.7315284441165957, 0.07948921428038187, 0.17812207030422753, 0.16743616370306638, 0.16442228962390776], 0.11802529423346594

# %%
# Define column 'type' as a string to avoid nan pandas errors.
df['type'] = df.type.astype(str)

# Preview the dataframe from the statefile, which will then be used to generate the data needed for the 
# LDAvis library. 
df[:4]
# Out:
#    #doc                   source  pos  typeindex        type  topic
# 0     0  data/OttAlg/gaid-36.txt    0          0  naaman-bey      9
# 1     0  data/OttAlg/gaid-36.txt    1          1         mai      5
# 2     0  data/OttAlg/gaid-36.txt    2          2        turc      5
# 3     0  data/OttAlg/gaid-36.txt    3          3   naissance      5

# %% [markdown]
# <b>Step 1:</b> We need the length of the documents. To do this, Jeri grouped the data by document id and counted the tokens in the doc. This data is then sorted by the doc id, so it will be in the correct order for visualization pre-processing.

# %%
# Get document lengths from statefile.
docs = df.groupby('#doc')['type'].count().reset_index(name='doc_length')

# Preview the gathered & grouped data:
docs[:4]
# Out:
#    #doc  doc_length
# 0     0         608
# 1     1           2
# 2     2          17
# 3     3         321

# %% [markdown]
# <b>Step 2:</b> We need the voabulary and frequencies. Jeri used pandas to generate a new frame with the word counts. She then sorted this df so that it is alphabetical by type, a step that will need to be repeated when creating the topic-term matrix because the order matters and must be kept consistent. Just as in Jeri's example, I, too, have OCR errors (see the first entry in the vocab dataframe above).

# %%
# Get vocab and term frequencies from the statefile.
vocab = df['type'].value_counts().reset_index()
vocab.columns = ['type', 'term_freq']
vocab = vocab.sort_values(by='type', ascending=True)

# Preview the resulting dataframe
vocab[:4]
# Out:
#               type  term_freq
# 15111        a*tes          1
# 8320      a-t-elle          1
# 4531        a-t-il          3
# 6374   abaissement          2

# %% [markdown]
# <b>Step 3:</b> Create matrix files. The values need to be smoothed and the data normalized so that each row sums to 1. Jeri used sklearn to handle large matrices efficiently.

# %%
# Topic-term matrix from state file.

import sklearn.preprocessing

def pivot_and_smooth(df, smooth_value, rows_variable, cols_variable, values_variable):
    """
    Turns the pandas dataframe into a data matrix.
    Args:
        df (dataframe): aggregated dataframe
        smooth_value (float): value to add to the matrix to account for the priors
        rows_variable (str): name of dataframe row to use as the rows in the matrix
        cols_variable (str): name of dataframe column to use as the columns in the matrix
        values_variable (str): name of the dataframe column to use as the values in the matrix
    Returns:
        dataframe: pandas matrix that has been normalized on the rows
    """
    matrix = df.pivot(index=rows_variable, columns=cols_variable, values=values_variable).fillna(value=0)
    matrix = matrix.values + smooth_value
    normed = sklearn.preprocessing.normalize(matrix, norm='l1', axis=1)
    return pd.DataFrame(normed)

# %% [markdown]
# <b>Step 4:</b> [From Jeri's post] Next, we need to aggregate the data from the statefile dataframe to get the nmber of topic assignments for words in the documents. For <b>phi</b>, the topic-term matrix, [she] aggregated by topic and word, counted the number of times each word was assigned to each topic, and then sorted the resulting dataframe alphabetically by word, so that it matches the order of the vocabulary frame. Here, [she] used the <b>beta</b> hyperparameter as the smoothing value.

# %%
phi_df = df.groupby(['topic', 'type'])['type'].count().reset_index(name ='token_count')
phi_df = phi_df.sort_values(by='type', ascending=True)

phi_df[:10]

phi = pivot_and_smooth(phi_df, beta, 'topic', 'type', 'token_count')

phi[:10]
# Out:
#       0         1         2         3         4         5         6      \
# 0  0.000025  0.000025  0.000233  0.000025  0.000025  0.000025  0.000025
# 1  0.000220  0.000023  0.000023  0.000023  0.000023  0.000023  0.000220
# 2  0.000023  0.000214  0.000023  0.000023  0.000023  0.000023  0.000023
# 3  0.000020  0.000020  0.000020  0.000020  0.000020  0.000020  0.000020
# 4  0.000016  0.000016  0.000283  0.000016  0.000149  0.000016  0.000016
# 5  0.000003  0.000003  0.000003  0.000003  0.000003  0.000026  0.000072
# 6  0.000019  0.000019  0.000019  0.000019  0.000019  0.000019  0.000019
# 7  0.000013  0.000013  0.000013  0.000013  0.000013  0.000013  0.000013
# 8  0.000013  0.000013  0.000013  0.000241  0.000013  0.000013  0.000013
# 9  0.000020  0.000020  0.000020  0.000020  0.000020  0.000020  0.000020
#
#       7         8         9        ...        16844     16845     16846  \
# 0  0.000025  0.000025  0.000233    ...     0.000025  0.000025  0.000025
# ...

# %% [markdown]
# <b>Step 5:</b> We do the same thing again, but focused on the documents and topics (rather than words & topics) to generate the <b>theta</b> document-topic matrix. Here, <b>alpha</b> is used as the smoothing value.

# %%
theta_df = df.groupby(['#doc', 'topic'])['topic'].count().reset_index(name ='topic_count')

theta_df[:10]

theta = pivot_and_smooth(theta_df, alpha, '#doc', 'topic', 'topic_count')

theta[:10]
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.000074  0.000363  0.000124  0.000215  0.000038  0.366282  0.000130
# 1  0.009336  0.046026  0.015726  0.027263  0.004777  0.774521  0.016499
# 2  0.002270  0.313946  0.003823  0.057087  0.001161  0.591968  0.004011
# 3  0.000139  0.028478  0.000234  0.000406  0.000071  0.521069  0.176270
# 4  0.000142  0.000702  0.000240  0.000416  0.003239  0.366450  0.000252
# 5  0.007731  0.038115  0.013023  0.022577  0.003956  0.813277  0.013663
# 6  0.009336  0.046026  0.015726  0.027263  0.004777  0.566959  0.016499
# 7  0.015294  0.018729  0.092298  0.048534  0.000015  0.466368  0.000716
# 8  0.010661  0.048076  0.000395  0.000685  0.000120  0.671113  0.000414
# 9  0.000105  0.000516  0.000176  0.000306  0.000054  0.429790  0.007165
#
#           7         8         9
# 0  0.452145  0.010097  0.170533
# 1  0.036971  0.034753  0.034128
# 2  0.008988  0.008449  0.008297
# 3  0.130253  0.000517  0.142563
# ...

# %% [markdown]
# The above processing steps represent about 90% of the work needed to prepare the mallet data for visualization with the LDAvis library. Now that all of the data has been formatted for pyLDAvis, we can queue it up and pass it to the visualization library.

# %%
import pyLDAvis

data = {'topic_term_dists': phi,
        'doc_topic_dists': theta,
        'doc_lengths': list(docs['doc_length']),
        'vocab': list(vocab['type']),
        'term_frequency': list(vocab['term_freq'])
}

vis_data = pyLDAvis.prepare(**data)

pyLDAvis.display(vis_data)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4117548095995208760255727"></div>
# <script type="text/javascript">
#
# ...
